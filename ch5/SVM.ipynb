# %%
import numpy as np
from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

iris = datasets.load_iris()
X = iris["data"][:, (2, 3)]
y = (iris["target"] == 2).astype(np.float64) # turn true, false array into float value!

svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("linear_svc", LinearSVC(C=1, loss="hinge")),
])

# %%
svm_clf.fit(X, y) #just train the model + put values into StandardScaler !
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear_svc', LinearSVC(C=1, loss='hinge'))])

# %%
svm_clf.predict([[5.5, 1.7]])
# Out:
# array([1.])

# %%
from sklearn.datasets import make_moons
from sklearn.preprocessing import PolynomialFeatures

X, y = make_moons(n_samples=100, noise=0.15)
polynomial_svm_clf = Pipeline([
    ("poly_features", PolynomialFeatures(degree=3)), # dimentions upto 3! 1d -> 3d ?
    ("scaler", StandardScaler()),
    ("svm_clf", LinearSVC(C=10, loss="hinge")),
])

# %%
print(X.shape)
print(X[0])
# Out:
# (100, 2)
# [0.28241775 0.82848988]

# %%
print(StandardScaler().fit_transform(PolynomialFeatures(degree=3).fit_transform(X))) #polynomialFeatures 사용해서 데이터 한개가 아닌 여러개의 관계 만들 수(0) !!
# Out:
# [[ 0.00000000e+00 -2.54847618e-01  1.19120810e+00 -7.67940668e-01
#    6.79516779e-01  1.25209483e+00 -4.75338623e-01 -3.09485321e-02
#    4.26813746e-01  1.17477819e+00]
#  [ 0.00000000e+00  7.51201819e-01  1.72139403e-01  2.68478779e-01
#    1.02944496e+00 -6.35287611e-01  1.08448750e-01  6.01244954e-01
#    1.43590015e-01 -4.25037846e-01]
#  [ 0.00000000e+00  9.42647235e-01 -4.84006851e-01  6.09002236e-01
#    1.25780569e-01 -9.80233458e-01  4.03475866e-01 -1.35748824e-01
#   -3.57221228e-01 -5.28503226e-01]
#  [ 0.00000000e+00  2.47122743e-01 -1.50551933e+00 -4.08978598e-01
#   -7.50286560e-01 -1.60397084e-01 -3.42480307e-01 -5.81931648e-01
#    3.80942282e-01 -9.07596641e-01]
#  [ 0.00000000e+00 -2.28636032e-01 -7.46637077e-01 -7.56991386e-01
#    2.62820280e-02 -9.27254056e-01 -4.73112963e-01 -1.61460896e-01
#   -3.37109878e-01 -5.34732789e-01]
#  [ 0.00000000e+00 -2.68820103e-01 -4.27315316e-01 -7.73426394e-01
# ...

# %%
polynomial_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('poly_features', PolynomialFeatures(degree=3)),
#                 ('scaler', StandardScaler()),
#                 ('svm_clf', LinearSVC(C=10, loss='hinge'))])

# %%
polynomial_svm_clf.predict([X[0]])
# Out:
# array([0])

# %%
y[0]
# Out:
# 0

# %%
from sklearn.svm import SVC
poly_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel="poly", degree=3, coef0=1, C=5))
])
poly_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=5, coef0=1, kernel='poly'))])

# %%
rbf_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel="rbf", gamma=5, C=0.001)),
])
rbf_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=0.001, gamma=5))])

# %%
from sklearn.svm import LinearSVR

svm_reg = LinearSVR(epsilon=1.5)
svm_reg.fit(X, y)
# Out:
# LinearSVR(epsilon=1.5)

# %%
from sklearn.svm import SVR
svm_poly_reg = SVR(kernel="poly", degree=2, C=100, epsilon=0.1)# C=100 means large margin error -> little constraint!
svm_poly_reg.fit(X, y)
# Out:
# SVR(C=100, degree=2, kernel='poly')
